# %% [markdown]
# <a href="https://colab.research.google.com/github/ParthibBiswas10/Data-Visualization-HacktoberFest-25/blob/Parthib/BallonDor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
players = ["Lionel Messi", "Cristiano Ronaldo", "Michel Platini", "Johan Cruyff",
           "Marco van Basten", "Franz Beckenbauer", "Ronaldo Nazário", "Di Stefano",
           "Kevin Keegan", "Rummenigge"]
wins = [8, 5, 3, 3, 3, 2, 2, 2, 2, 2]

# %%
plt.figure(figsize=(12,6))
plt.barh(players[::-1], wins[::-1], color='gold')
plt.xlabel("Number of Ballon d'Or Wins")
plt.title("Top 10 Players with Most Ballon d'Or Wins")
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()
