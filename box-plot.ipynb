# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
data = np.random.normal(loc=50, scale=15, size=200)

# %%
plt.boxplot(data)
plt.title('Boxplot of Generated Dataset')
plt.ylabel('Value')
plt.show()
