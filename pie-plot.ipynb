# %%
import pandas as pd
import seaborn as sns

# %%
data = {
    'Category': ['A', 'B', 'C', 'D'],
    'Value': [30, 15, 45, 10]
}
df = pd.DataFrame(data)

# %%
plt.figure(figsize=(6,6))
plt.pie(df['Value'], labels=df['Category'], autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.title('Category Distribution')
plt.show()
